# %%
import pandas as pd
import os
import re
from datetime import datetime

fn_list = os.listdir("data/after-nlp-pipeline")

#after-scraping-08-29-2019-01-15-09.csv
dates = list(map(lambda x: {'fileName': x, 'date': re.search("([0-9]{2}\-[0-9]{2}\-[0-9]{4}-[0-9]{2}-[0-9]{2}-[0-9]{2})", x).group()}, fn_list)) 
dates = list(map(lambda x: {'fileName': x['fileName'], 'date': datetime.strptime(x['date'], "%m-%d-%Y-%H-%M-%S")}, dates))
dates.sort(key=lambda x: x['date'], reverse=True)

fn_newest = dates[0]['fileName']

f = open("data/after-nlp-pipeline/{}".format(fn_newest), 'r', encoding="utf-8")
df = pd.read_csv(f, index_col=0, converters={'text_scraped_words': lambda x: x[1:-1].replace("'", "").split(', ')})
f.close()

print("Successfully imported file: {}".format(fn_newest))
# Out:
# Successfully imported file: after-nlp-pipeline-09-16-2019-17-46-53.csv

# %%
df
# Out:
#                                                   text  \
# 0    Around 40% of all the websites on the internet...
# 1    Cybercriminals have taken advantage of the unp...
# 2    The flaw has been tracked as CVE-2019-9506 and...
# 3    The app exposed real-time chats and private ch...
# 4    The newer variant initially downloads a JavaSc...
# ..                                                 ...
# 113  The scientists&#x2019; rogue engineering works...
# 114  "It’s not Apple Pay itself, it's purely an exp...
# 115  Online scammers are now targeting readers of n...
# 116  Black Hat Black Hat founder Jeff Moss opened t...
# 117  Air New Zealand suffered a data breach comprom...
#
#                                                  title  \
# 0    Millions of web servers exposed to DoS attacks...
# 1    Misconfigured MongoDB database leaks 700,000 C...
# 2    Newly discovered KNOB flaw found infecting Blu...
# 3    Chinese App Sweet Chat Exposes 10M Users’ Chat...
# 4    New variant of Troldesh Ransomware targets vic...
# ..                                                 ...
# 113  Vulnerabilities in Siemens’ most secure indust...
# 114  How Apple Pay Buttons Can Make Websites Less Safe
# 115  Cheaters targeting Malaysiakini readers in cre...
# 116  Hack computers to steal someone's identity in ...
# 117  Air New Zealand suffers data breach impacting ...
#
#                                                  image card_type        id  \
# 0    https://cystory-images.s3.amazonaws.com/shutte...         P  6ae8a683
# 1    https://cystory-images.s3.amazonaws.com/iStock...         P  8894a252
# 2    https://cystory-images.s3.amazonaws.com/shutte...         P  d6ecc9c0
# 3    https://cystory-images.s3.amazonaws.com/shutte...         P  5afbeadc
# 4    https://cystory-images.s3.amazonaws.com/shutte...         P  42259560
# ..                                                 ...       ...       ...
# 113  https://cyware-ent.s3.amazonaws.com/image_bank...         P  20e8b149
# 114  https://cyware-ent.s3.amazonaws.com/image_bank...         P  d831128e
# 115  https://cyware-ent.s3.amazonaws.com/image_bank...         P  9bd83440
# 116  https://cyware-ent.s3.amazonaws.com/image_bank...         P  bf4e5107
# 117  https://cystory-images.s3.amazonaws.com/iStock...         P  fd862028
#
#            time      p_time  \
# 0    1565793505  1565793000
# 1    1565698811  1565791200
# 2    1565784839  1565784000
# 3    1565701200  1565701200
# 4    1565696421  1565697600
# ..          ...         ...
# 113  1565352869  1565352869
# 114  1565344389  1565352000
# 115  1565350237  1565352000
# 116  1565351507  1565352000
# 117  1565354663  1565352000
#
#                                                sp_link  \
# 0    https://cyware.com/news/millions-of-web-server...
# 1    https://cyware.com/news/misconfigured-mongodb-...
# 2    https://cyware.com/news/newly-discovered-knob-...
# 3    https://cyware.com/news/chinese-app-sweet-chat...
# 4    https://cyware.com/news/new-variant-of-troldes...
# ..                                                 ...
# 113  https://www.helpnetsecurity.com/2019/08/09/sie...
# 114  https://www.wired.com/story/apple-pay-server-s...
# 115  https://sg.news.yahoo.com/cheaters-targeting-m...
# 116  https://www.theregister.co.uk/2019/08/07/black...
# 117  https://cyware.com/news/air-new-zealand-suffer...
#
#                                            web_sp_link          sp_display  \
# 0    https://cyware.com/news/millions-of-web-server...  Cyware Hacker News
# 1    https://cyware.com/news/misconfigured-mongodb-...  Cyware Hacker News
# 2    https://cyware.com/news/newly-discovered-knob-...  Cyware Hacker News
# 3    https://cyware.com/news/chinese-app-sweet-chat...  Cyware Hacker News
# 4    https://cyware.com/news/new-variant-of-troldes...  Cyware Hacker News
# ..                                                 ...                 ...
# 113  https://www.helpnetsecurity.com/2019/08/09/sie...   Help Net Security
# 114  https://www.wired.com/story/apple-pay-server-s...               Wired
# 115  https://sg.news.yahoo.com/cheaters-targeting-m...      Yahoo! Finance
# 116  https://www.theregister.co.uk/2019/08/07/black...        The Register
# 117  https://cyware.com/news/air-new-zealand-suffer...  Cyware Hacker News
#
#      ... likes  comment_count is_archived is_bookmarked is_liked  \
# 0    ...     0              0       False         False    False
# 1    ...     0              0       False         False    False
# 2    ...     0              0       False         False    False
# 3    ...     0              0       False         False    False
# 4    ...     0              1       False         False    False
# ..   ...   ...            ...         ...           ...      ...
# 113  ...     0              0       False         False    False
# 114  ...     0              0       False         False    False
# 115  ...     0              0       False         False    False
# 116  ...     0              0       False         False    False
# 117  ...     0              0       False         False    False
#
#                                           text_scraped  \
# 0    Around 40% of all the websites on the internet...
# 1    Cybercriminals have taken advantage of the unp...
# 2    The flaw has been tracked as CVE-2019-9506 and...
# 3    The app exposed real-time chats and private ch...
# 4    The newer variant initially downloads a JavaSc...
# ..                                                 ...
# 113  Critical vulnerabilities in the Siemens S7 Sim...
# 114  Apple Pay has a slew of protective features th...
# 115  Online scammers are now targeting readers of n...
# 116  Black Hat Black Hat founder Jeff Moss opened t...
# 117  Air New Zealand suffered a data breach comprom...
#
#                                     text_scraped_words  \
# 0    [Around, 40%, of, all, the, websites, on, the,...
# 1    [Cybercriminals, have, taken, advantage, of, t...
# 2    [The, flaw, has, been, tracked, as, CVE-2019-9...
# 3    [The, app, exposed, real-time, chats, and, pri...
# 4    [The, newer, variant, initially, downloads, a,...
# ..                                                 ...
# 113  [Critical, vulnerabilities, in, the, Siemens, ...
# 114  [Apple, Pay, has, a, slew, of, protective, fea...
# 115  [Online, scammers, are, now, targeting, reader...
# 116  [Black, Hat, Black, Hat, founder, Jeff, Moss, ...
# 117  [Air, New, Zealand, suffered, a, data, breach,...
#
#      text_scraped_words_count  \
# 0                         340
# 1                         234
# 2                         399
# 3                         284
# 4                         533
# ..                        ...
# 113                       594
# 114                       593
# 115                       262
# 116                       562
# 117                       429
#
#                                        text_lemmatized  \
# 0    ['40', '%', 'website', 'internet', 'could', 'b...
# 1    ['cybercriminals', 'have', 'take', 'advantage'...
# 2    ['flaw', 'have', 'be', 'track', 'cve-2019', '9...
# 3    ['app', 'expose', 'time', 'chat', '10', 'milli...
# 4    ['variant', 'download', 'javascript', 'host', ...
# ..                                                 ...
# 113  ['vulnerability', 'siemens', 's7', 'simatic', ...
# 114  ['apple', 'pay', 'have', 'slew', 'feature', 'm...
# 115  ['online', 'scammer', 'be', 'target', 'reader'...
# 116  ['black', 'hat', 'founder', 'jeff', 'moss', 'o...
# 117  ['air', 'new', 'zealand', 'suffer', 'data', 'b...
#
#                                               text_ner
# 0    ['40:PERCENT', '%:PERCENT', 'DoS:ORG', 'Amazon...
# 1    ['700,000:CARDINAL', 'customers’:ORG', 'Choice...
# 2    ['CVE-2019:ORG', '9506:ORG', 'two:CARDINAL', '...
# 3    ['10:CARDINAL', 'million:CARDINAL', 'Darryl:PE...
# 4    ['JavaScript:ORG', 'two:CARDINAL', 'Troldesh:W...
# ..                                                 ...
# 113  ['Siemens:ORG', 'Tel:ORG', 'Aviv:ORG', 'Univer...
# 114  ['Apple:ORG', 'Pay:ORG', '2016:DATE', 'Black:P...
# 115  ['Malaysiakini:ORG', 'KUALA:FAC', 'LUMPUR:FAC'...
# 116  ['Jeff:PERSON', 'Moss:PERSON', 'year:DATE', 'L...
# 117  ['Air:ORG', 'New:ORG', 'Zealand:ORG', 'Airpoin...
#
# [100 rows x 25 columns]
