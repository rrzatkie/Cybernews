# %%
# %%bash
# pwd
# echo '============'
# uname -a
# echo '============'
# free -m
# echo '============'
# df -h
# echo '============'
# hostname
# echo '============'
# cat /etc/passwd
# echo '============'
# ls /
# echo '============'
# echo $PATH
# Out:
# /mnt/c/Projects/Cybernews/Notebooks
# ...
# Linux DESKTOP-HOME 4.4.0-18362-Microsoft #1-Microsoft Mon Mar 18 12:02:00 PST 2019 x86_64 x86_64 x86_64 GNU/Linux
# ...
#               total        used        free      shared  buff/cache   available
# Mem:          32717       10891       21594          17         230       21687
# Swap:         60971        4264       56707
# ...
# Filesystem      Size  Used Avail Use% Mounted on
# rootfs          477G  361G  116G  76% /
# none            477G  361G  116G  76% /dev
# none            477G  361G  116G  76% /run
# none            477G  361G  116G  76% /run/lock
# none            477G  361G  116G  76% /run/shm
# none            477G  361G  116G  76% /run/user
# cgroup          477G  361G  116G  76% /sys/fs/cgroup
# C:\             477G  361G  116G  76% /mnt/c
# ...
# DESKTOP-HOME
# ...
# root:x:0:0:root:/root:/bin/bash
# daemon:x:1:1:daemon:/usr/sbin:/usr/sbin/nologin
# bin:x:2:2:bin:/bin:/usr/sbin/nologin
# sys:x:3:3:sys:/dev:/usr/sbin/nologin
# ...
